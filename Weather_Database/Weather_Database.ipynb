# %%
# Import the dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import gmaps

# Import API key
from config import g_key
# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitudes and Longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size =2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we wil add it to the cities list 
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficent count
len(cities)
# Out:
# 750

# %%
# Establish the URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sumenep
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | hamilton
# Processing Record 8 of Set 1 | general cepeda
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | tautira
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | pendleton
# Processing Record 20 of Set 1 | cairns
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | bonavista
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | pundaguitan
# Processing Record 32 of Set 1 | cap-aux-meules
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | rio grande
# Processing Record 36 of Set 1 | noumea
# Processing Record 37 of Set 1 | aviles
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | mecca
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | xichang
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | marathon
# Processing Record 48 of Set 1 | san isidro
# Processing Record 49 of Set 1 | san cristobal
# Processing Record 50 of Set 1 | buchanan
# Processing Record 1 of Set 2 | lufilufi
# Processing Record 2 of Set 2 | saint anthony
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | toda bhim
# City not found. Skipping...
# Processing Record 7 of Set 2 | belaya gora
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | champerico
# Processing Record 13 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 2 | naryan-mar
# Processing Record 15 of Set 2 | rocha
# Processing Record 16 of Set 2 | nurota
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | lere
# Processing Record 21 of Set 2 | langsa
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | hatillo
# Processing Record 26 of Set 2 | iskateley
# Processing Record 27 of Set 2 | pimenta bueno
# Processing Record 28 of Set 2 | elko
# Processing Record 29 of Set 2 | novyy urengoy
# Processing Record 30 of Set 2 | sompeta
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | sapa
# Processing Record 35 of Set 2 | okha
# Processing Record 36 of Set 2 | arak
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | northam
# Processing Record 39 of Set 2 | longido
# Processing Record 40 of Set 2 | shimanovsk
# Processing Record 41 of Set 2 | teruel
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | ostrovnoy
# Processing Record 44 of Set 2 | najran
# Processing Record 45 of Set 2 | jalu
# Processing Record 46 of Set 2 | kahului
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | bussigny
# Processing Record 50 of Set 2 | te anau
# Processing Record 1 of Set 3 | tura
# Processing Record 2 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 3 | amazar
# Processing Record 4 of Set 3 | znamenskoye
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | yenagoa
# Processing Record 8 of Set 3 | beringovskiy
# Processing Record 9 of Set 3 | port hedland
# Processing Record 10 of Set 3 | muros
# Processing Record 11 of Set 3 | yabrud
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | linares
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | corbelia
# Processing Record 19 of Set 3 | arica
# Processing Record 20 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 3 | ahipara
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | lakes entrance
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | harper
# Processing Record 28 of Set 3 | bubaque
# Processing Record 29 of Set 3 | mareeba
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 3 | puerto escondido
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | bilma
# Processing Record 35 of Set 3 | ketchikan
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | albany
# Processing Record 38 of Set 3 | udachnyy
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | asosa
# Processing Record 42 of Set 3 | ko samui
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | morden
# Processing Record 46 of Set 3 | palmares do sul
# Processing Record 47 of Set 3 | muncar
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | saint-pierre
# Processing Record 50 of Set 3 | butaritari
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | batagay
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 4 | palmer
# Processing Record 6 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 4 | seredka
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | port hardy
# Processing Record 12 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | belmonte
# Processing Record 15 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | the pas
# Processing Record 19 of Set 4 | bathsheba
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | tuatapere
# Processing Record 22 of Set 4 | coahuayana
# Processing Record 23 of Set 4 | frutal
# Processing Record 24 of Set 4 | amposta
# Processing Record 25 of Set 4 | cabildo
# Processing Record 26 of Set 4 | alta floresta
# Processing Record 27 of Set 4 | kebemer
# City not found. Skipping...
# Processing Record 28 of Set 4 | labuhan
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | yar-sale
# Processing Record 31 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 4 | portland
# Processing Record 33 of Set 4 | ayia galini
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | the village
# Processing Record 36 of Set 4 | lukulu
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | qaqortoq
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | husavik
# Processing Record 42 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 4 | dakar
# Processing Record 44 of Set 4 | komsomolskiy
# Processing Record 45 of Set 4 | lovozero
# Processing Record 46 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 4 | acajutla
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | nome
# Processing Record 50 of Set 4 | richmond
# Processing Record 1 of Set 5 | gao
# Processing Record 2 of Set 5 | santa cruz
# Processing Record 3 of Set 5 | garm
# City not found. Skipping...
# Processing Record 4 of Set 5 | nara
# Processing Record 5 of Set 5 | makaha
# Processing Record 6 of Set 5 | shakiso
# Processing Record 7 of Set 5 | baley
# Processing Record 8 of Set 5 | srandakan
# Processing Record 9 of Set 5 | havelock
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | catalao
# Processing Record 12 of Set 5 | kieta
# Processing Record 13 of Set 5 | barabai
# Processing Record 14 of Set 5 | sabang
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | jinan
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | danane
# Processing Record 19 of Set 5 | monrovia
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | adrar
# Processing Record 23 of Set 5 | santa rosa
# Processing Record 24 of Set 5 | bay roberts
# Processing Record 25 of Set 5 | revyakino
# Processing Record 26 of Set 5 | chernyshevskiy
# Processing Record 27 of Set 5 | poronaysk
# Processing Record 28 of Set 5 | sistranda
# Processing Record 29 of Set 5 | pasni
# Processing Record 30 of Set 5 | reforma
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | pochutla
# Processing Record 33 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 5 | pangody
# Processing Record 37 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 5 | kensington
# Processing Record 39 of Set 5 | hanyang
# Processing Record 40 of Set 5 | matara
# Processing Record 41 of Set 5 | teknaf
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | bambanglipuro
# Processing Record 44 of Set 5 | kabare
# Processing Record 45 of Set 5 | jishou
# Processing Record 46 of Set 5 | kupang
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | raduzhnyy
# Processing Record 49 of Set 5 | cabo san lucas
# Processing Record 50 of Set 5 | pevek
# Processing Record 1 of Set 6 | zhigansk
# Processing Record 2 of Set 6 | nerchinskiy zavod
# Processing Record 3 of Set 6 | ca mau
# Processing Record 4 of Set 6 | kaitangata
# Processing Record 5 of Set 6 | villa bisono
# Processing Record 6 of Set 6 | kumbo
# Processing Record 7 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 6 | kiama
# Processing Record 10 of Set 6 | iskilip
# Processing Record 11 of Set 6 | timmins
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | tshikapa
# Processing Record 14 of Set 6 | seminole
# Processing Record 15 of Set 6 | jacareacanga
# Processing Record 16 of Set 6 | urumqi
# Processing Record 17 of Set 6 | aykino
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | guaruja
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | marabba
# Processing Record 22 of Set 6 | kafanchan
# Processing Record 23 of Set 6 | oktyabrskiy
# Processing Record 24 of Set 6 | iquique
# Processing Record 25 of Set 6 | hallingby
# City not found. Skipping...
# Processing Record 26 of Set 6 | cloquet
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | beaverlodge
# Processing Record 29 of Set 6 | aklavik
# Processing Record 30 of Set 6 | lazaro cardenas
# Processing Record 31 of Set 6 | luba
# Processing Record 32 of Set 6 | chokurdakh
# Processing Record 33 of Set 6 | pangnirtung
# Processing Record 34 of Set 6 | mana
# Processing Record 35 of Set 6 | ptuj
# Processing Record 36 of Set 6 | sisimiut
# Processing Record 37 of Set 6 | lock haven
# Processing Record 38 of Set 6 | high rock
# Processing Record 39 of Set 6 | la palma
# Processing Record 40 of Set 6 | khandyga
# Processing Record 41 of Set 6 | mayya
# Processing Record 42 of Set 6 | hasaki
# Processing Record 43 of Set 6 | luwuk
# Processing Record 44 of Set 6 | lavrentiya
# Processing Record 45 of Set 6 | yerbogachen
# Processing Record 46 of Set 6 | strezhevoy
# Processing Record 47 of Set 6 | terre haute
# Processing Record 48 of Set 6 | waldoboro
# Processing Record 49 of Set 6 | banda aceh
# Processing Record 50 of Set 6 | cedar city
# Processing Record 1 of Set 7 | dzerzhinskoye
# Processing Record 2 of Set 7 | okmulgee
# Processing Record 3 of Set 7 | dogbo
# Processing Record 4 of Set 7 | airai
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | seoul
# Processing Record 7 of Set 7 | chuy
# Processing Record 8 of Set 7 | yumen
# Processing Record 9 of Set 7 | karratha
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | beloha
# Processing Record 12 of Set 7 | orlik
# Processing Record 13 of Set 7 | taga
# Processing Record 14 of Set 7 | otofuke
# Processing Record 15 of Set 7 | canon city
# Processing Record 16 of Set 7 | qandala
# Processing Record 17 of Set 7 | san jose
# Processing Record 18 of Set 7 | ballina
# Processing Record 19 of Set 7 | poum
# Processing Record 20 of Set 7 | manhattan
# Processing Record 21 of Set 7 | khilok
# Processing Record 22 of Set 7 | qui nhon
# Processing Record 23 of Set 7 | touros
# Processing Record 24 of Set 7 | chuzhou
# Processing Record 25 of Set 7 | enumclaw
# Processing Record 26 of Set 7 | taltal
# Processing Record 27 of Set 7 | hambantota
# Processing Record 28 of Set 7 | kizilskoye
# Processing Record 29 of Set 7 | shenjiamen
# Processing Record 30 of Set 7 | padang
# Processing Record 31 of Set 7 | mahon
# Processing Record 32 of Set 7 | bud
# Processing Record 33 of Set 7 | leh
# Processing Record 34 of Set 7 | half moon bay
# Processing Record 35 of Set 7 | robertsport
# Processing Record 36 of Set 7 | porbandar
# Processing Record 37 of Set 7 | mantua
# Processing Record 38 of Set 7 | maceio
# Processing Record 39 of Set 7 | bandarbeyla
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | jhanjharpur
# Processing Record 42 of Set 7 | anloga
# Processing Record 43 of Set 7 | scottsbluff
# Processing Record 44 of Set 7 | aromashevo
# Processing Record 45 of Set 7 | dingle
# Processing Record 46 of Set 7 | maningrida
# Processing Record 47 of Set 7 | chkalovsk
# Processing Record 48 of Set 7 | san quintin
# Processing Record 49 of Set 7 | kallithea
# Processing Record 50 of Set 7 | nacozari
# Processing Record 1 of Set 8 | gravina in puglia
# Processing Record 2 of Set 8 | ust-tsilma
# Processing Record 3 of Set 8 | shache
# Processing Record 4 of Set 8 | ambilobe
# Processing Record 5 of Set 8 | casimiro castillo
# Processing Record 6 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 8 | hendek
# Processing Record 8 of Set 8 | kudahuvadhoo
# Processing Record 9 of Set 8 | los llanos de aridane
# Processing Record 10 of Set 8 | qasigiannguit
# Processing Record 11 of Set 8 | constantine
# Processing Record 12 of Set 8 | colgong
# Processing Record 13 of Set 8 | riyadh
# Processing Record 14 of Set 8 | hovd
# Processing Record 15 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 8 | clyde river
# Processing Record 17 of Set 8 | malakal
# Processing Record 18 of Set 8 | uddevalla
# Processing Record 19 of Set 8 | maniitsoq
# Processing Record 20 of Set 8 | althofen
# Processing Record 21 of Set 8 | muisne
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | zhanakorgan
# Processing Record 24 of Set 8 | lebu
# Processing Record 25 of Set 8 | saint simons
# Processing Record 26 of Set 8 | avera
# Processing Record 27 of Set 8 | mattru
# Processing Record 28 of Set 8 | caravelas
# Processing Record 29 of Set 8 | sanlucar la mayor
# Processing Record 30 of Set 8 | ulaangom
# Processing Record 31 of Set 8 | yaring
# Processing Record 32 of Set 8 | klerksdorp
# Processing Record 33 of Set 8 | melilla
# Processing Record 34 of Set 8 | katsuura
# Processing Record 35 of Set 8 | nadym
# Processing Record 36 of Set 8 | esmeraldas
# Processing Record 37 of Set 8 | kentau
# Processing Record 38 of Set 8 | bilibino
# Processing Record 39 of Set 8 | vestmannaeyjar
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | flinders
# Processing Record 42 of Set 8 | sambava
# Processing Record 43 of Set 8 | mugur-aksy
# Processing Record 44 of Set 8 | rudbar
# Processing Record 45 of Set 8 | namibe
# Processing Record 46 of Set 8 | ixtapa
# Processing Record 47 of Set 8 | bull savanna
# Processing Record 48 of Set 8 | galveston
# Processing Record 49 of Set 8 | kuva
# City not found. Skipping...
# Processing Record 50 of Set 8 | lata
# Processing Record 1 of Set 9 | kitwe
# Processing Record 2 of Set 9 | lerwick
# Processing Record 3 of Set 9 | faya
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | bereda
# Processing Record 6 of Set 9 | luderitz
# Processing Record 7 of Set 9 | medea
# Processing Record 8 of Set 9 | mandalgovi
# Processing Record 9 of Set 9 | dali
# Processing Record 10 of Set 9 | sangar
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 13 of Set 9 | zhuhai
# Processing Record 14 of Set 9 | borger
# Processing Record 15 of Set 9 | melfi
# Processing Record 16 of Set 9 | bayji
# Processing Record 17 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 9 | callaway
# Processing Record 19 of Set 9 | ossora
# Processing Record 20 of Set 9 | talnakh
# Processing Record 21 of Set 9 | castrillon
# Processing Record 22 of Set 9 | luau
# Processing Record 23 of Set 9 | mnogovershinnyy
# Processing Record 24 of Set 9 | fereydunshahr
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | praia da vitoria
# Processing Record 27 of Set 9 | pavilosta
# Processing Record 28 of Set 9 | kosa
# Processing Record 29 of Set 9 | necochea
# Processing Record 30 of Set 9 | aden
# Processing Record 31 of Set 9 | burpengary
# Processing Record 32 of Set 9 | baiao
# Processing Record 33 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 9 | sur
# Processing Record 35 of Set 9 | nyazepetrovsk
# Processing Record 36 of Set 9 | atherton
# Processing Record 37 of Set 9 | iranshahr
# Processing Record 38 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 39 of Set 9 | juneau
# Processing Record 40 of Set 9 | atasu
# Processing Record 41 of Set 9 | kalangala
# Processing Record 42 of Set 9 | sao filipe
# Processing Record 43 of Set 9 | chifeng
# Processing Record 44 of Set 9 | saint-augustin
# Processing Record 45 of Set 9 | cookeville
# Processing Record 46 of Set 9 | fonte boa
# Processing Record 47 of Set 9 | onega
# Processing Record 48 of Set 9 | axim
# Processing Record 49 of Set 9 | inuvik
# Processing Record 50 of Set 9 | poli
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 10 | egvekinot
# Processing Record 4 of Set 10 | quelimane
# Processing Record 5 of Set 10 | cayenne
# Processing Record 6 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 10 | saint-joseph
# Processing Record 8 of Set 10 | rimini
# Processing Record 9 of Set 10 | gillette
# Processing Record 10 of Set 10 | superior
# Processing Record 11 of Set 10 | buala
# Processing Record 12 of Set 10 | takoradi
# Processing Record 13 of Set 10 | menongue
# Processing Record 14 of Set 10 | requena
# Processing Record 15 of Set 10 | mogapinyana
# Processing Record 16 of Set 10 | muzhi
# Processing Record 17 of Set 10 | chumphon
# Processing Record 18 of Set 10 | itoman
# Processing Record 19 of Set 10 | jiaohe
# Processing Record 20 of Set 10 | siderno
# Processing Record 21 of Set 10 | lagos
# Processing Record 22 of Set 10 | prince rupert
# Processing Record 23 of Set 10 | hudiksvall
# Processing Record 24 of Set 10 | meulaboh
# Processing Record 25 of Set 10 | baykit
# Processing Record 26 of Set 10 | itambe
# Processing Record 27 of Set 10 | atar
# Processing Record 28 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 29 of Set 10 | sechura
# Processing Record 30 of Set 10 | mitrofanovka
# Processing Record 31 of Set 10 | gwadar
# Processing Record 32 of Set 10 | diglur
# Processing Record 33 of Set 10 | manta
# Processing Record 34 of Set 10 | saposoa
# Processing Record 35 of Set 10 | mercedes
# Processing Record 36 of Set 10 | khasan
# Processing Record 37 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 10 | zarumilla
# Processing Record 39 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 10 | oksfjord
# Processing Record 41 of Set 10 | de-kastri
# Processing Record 42 of Set 10 | kyzyl-suu
# Processing Record 43 of Set 10 | caraballeda
# Processing Record 44 of Set 10 | port-gentil
# Processing Record 45 of Set 10 | mananjary
# Processing Record 46 of Set 10 | lompoc
# Processing Record 47 of Set 10 | teahupoo
# Processing Record 48 of Set 10 | meiganga
# Processing Record 49 of Set 10 | chino valley
# Processing Record 50 of Set 10 | sovetskiy
# Processing Record 1 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 11 | lasa
# Processing Record 3 of Set 11 | lodja
# Processing Record 4 of Set 11 | sidney
# Processing Record 5 of Set 11 | korla
# Processing Record 6 of Set 11 | papetoai
# Processing Record 7 of Set 11 | merauke
# Processing Record 8 of Set 11 | tolmezzo
# Processing Record 9 of Set 11 | rawson
# Processing Record 10 of Set 11 | naze
# Processing Record 11 of Set 11 | vao
# Processing Record 12 of Set 11 | vanavara
# Processing Record 13 of Set 11 | santiago
# Processing Record 14 of Set 11 | ilheus
# Processing Record 15 of Set 11 | arteaga
# Processing Record 16 of Set 11 | grindavik
# Processing Record 17 of Set 11 | bolobo
# Processing Record 18 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 19 of Set 11 | deputatskiy
# Processing Record 20 of Set 11 | campeche
# Processing Record 21 of Set 11 | west bay
# Processing Record 22 of Set 11 | beja
# Processing Record 23 of Set 11 | akdepe
# Processing Record 24 of Set 11 | thinadhoo
# Processing Record 25 of Set 11 | angoche
# Processing Record 26 of Set 11 | placerville
# Processing Record 27 of Set 11 | dufftown
# Processing Record 28 of Set 11 | chegdomyn
# Processing Record 29 of Set 11 | mikun
# Processing Record 30 of Set 11 | grand baie
# Processing Record 31 of Set 11 | alyangula
# Processing Record 32 of Set 11 | omsukchan
# Processing Record 33 of Set 11 | paita
# Processing Record 34 of Set 11 | tucurui
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | batsfjord
# Processing Record 37 of Set 11 | burica
# City not found. Skipping...
# Processing Record 38 of Set 11 | benghazi
# Processing Record 39 of Set 11 | columbus
# Processing Record 40 of Set 11 | copiapo
# Processing Record 41 of Set 11 | xiaoshi
# Processing Record 42 of Set 11 | boundiali
# Processing Record 43 of Set 11 | boa vista
# Processing Record 44 of Set 11 | birao
# Processing Record 45 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 11 | whyalla
# Processing Record 47 of Set 11 | quatre cocos
# Processing Record 48 of Set 11 | nokha
# Processing Record 49 of Set 11 | krasnoselkup
# Processing Record 50 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 12 | abu dhabi
# Processing Record 2 of Set 12 | ostersund
# Processing Record 3 of Set 12 | westport
# Processing Record 4 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 12 | tateyama
# Processing Record 6 of Set 12 | waddan
# Processing Record 7 of Set 12 | araouane
# Processing Record 8 of Set 12 | baglan
# Processing Record 9 of Set 12 | mahibadhoo
# Processing Record 10 of Set 12 | gat
# Processing Record 11 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 12 | ternate
# Processing Record 13 of Set 12 | chaman
# Processing Record 14 of Set 12 | nizhniy kuranakh
# Processing Record 15 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 16 of Set 12 | suba
# Processing Record 17 of Set 12 | ponta delgada
# Processing Record 18 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 12 | waingapu
# Processing Record 20 of Set 12 | samarai
# Processing Record 21 of Set 12 | koumac
# Processing Record 22 of Set 12 | olinda
# Processing Record 23 of Set 12 | bukachacha
# Processing Record 24 of Set 12 | prnjavor
# Processing Record 25 of Set 12 | novaya ladoga
# Processing Record 26 of Set 12 | victoria
# Processing Record 27 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 28 of Set 12 | cockburn town
# Processing Record 29 of Set 12 | jacqueville
# Processing Record 30 of Set 12 | play cu
# City not found. Skipping...
# Processing Record 31 of Set 12 | goderich
# Processing Record 32 of Set 12 | mokhsogollokh
# Processing Record 33 of Set 12 | grand gaube
# Processing Record 34 of Set 12 | lerici
# Processing Record 35 of Set 12 | maputo
# Processing Record 36 of Set 12 | silver city
# Processing Record 37 of Set 12 | umm kaddadah
# Processing Record 38 of Set 12 | coxim
# Processing Record 39 of Set 12 | malyye derbety
# Processing Record 40 of Set 12 | vilcun
# Processing Record 41 of Set 12 | paraiso
# Processing Record 42 of Set 12 | ulety
# Processing Record 43 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 12 | chabahar
# Processing Record 45 of Set 12 | ust-kuyga
# Processing Record 46 of Set 12 | bar harbor
# Processing Record 47 of Set 12 | mopipi
# Processing Record 48 of Set 12 | vagay
# Processing Record 49 of Set 12 | fairbanks
# Processing Record 50 of Set 12 | masterton
# Processing Record 1 of Set 13 | marawi
# Processing Record 2 of Set 13 | sungairaya
# Processing Record 3 of Set 13 | laela
# Processing Record 4 of Set 13 | mitsamiouli
# Processing Record 5 of Set 13 | choszczno
# Processing Record 6 of Set 13 | vila
# Processing Record 7 of Set 13 | bafoussam
# Processing Record 8 of Set 13 | fredericksburg
# Processing Record 9 of Set 13 | liku
# Processing Record 10 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 12 of Set 13 | lima
# Processing Record 13 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 13 | marsa matruh
# Processing Record 15 of Set 13 | mumford
# Processing Record 16 of Set 13 | abu kamal
# Processing Record 17 of Set 13 | ayan
# Processing Record 18 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 19 of Set 13 | brae
# Processing Record 20 of Set 13 | raga
# Processing Record 21 of Set 13 | ranong
# Processing Record 22 of Set 13 | morondava
# Processing Record 23 of Set 13 | akhmeta
# Processing Record 24 of Set 13 | nelson bay
# Processing Record 25 of Set 13 | smirnykh
# Processing Record 26 of Set 13 | baturaja
# Processing Record 27 of Set 13 | brindisi
# Processing Record 28 of Set 13 | cabo rojo
# Processing Record 29 of Set 13 | san policarpo
# Processing Record 30 of Set 13 | abu samrah
# Processing Record 31 of Set 13 | hay river
# Processing Record 32 of Set 13 | san martin
# Processing Record 33 of Set 13 | vestmanna
# Processing Record 34 of Set 13 | mitu
# Processing Record 35 of Set 13 | rio gallegos
# Processing Record 36 of Set 13 | ramhormoz
# Processing Record 37 of Set 13 | darova
# Processing Record 38 of Set 13 | chicama
# Processing Record 39 of Set 13 | lamu
# Processing Record 40 of Set 13 | kiknur
# Processing Record 41 of Set 13 | lavumisa
# Processing Record 42 of Set 13 | barra do corda
# Processing Record 43 of Set 13 | kyabe
# Processing Record 44 of Set 13 | kavaratti
# Processing Record 45 of Set 13 | pereira barreto
# Processing Record 46 of Set 13 | maragogi
# Processing Record 47 of Set 13 | totness
# Processing Record 48 of Set 13 | zhicheng
# Processing Record 49 of Set 13 | kaeo
# Processing Record 50 of Set 13 | burnie
# Processing Record 1 of Set 14 | juxian
# City not found. Skipping...
# Processing Record 2 of Set 14 | sibu
# Processing Record 3 of Set 14 | kokopo
# Processing Record 4 of Set 14 | yarensk
# Processing Record 5 of Set 14 | karpathos
# Processing Record 6 of Set 14 | merke
# Processing Record 7 of Set 14 | anadyr
# Processing Record 8 of Set 14 | tamandare
# Processing Record 9 of Set 14 | honiara
# Processing Record 10 of Set 14 | huntington
# Processing Record 11 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 14 | boke
# Processing Record 13 of Set 14 | trujillo
# Processing Record 14 of Set 14 | vostok
# Processing Record 15 of Set 14 | gamba
# Processing Record 16 of Set 14 | soe
# Processing Record 17 of Set 14 | safaga
# Processing Record 18 of Set 14 | california city
# Processing Record 19 of Set 14 | abnub
# Processing Record 20 of Set 14 | khash
# Processing Record 21 of Set 14 | nyurba
# Processing Record 22 of Set 14 | celestun
# Processing Record 23 of Set 14 | xining
# Processing Record 24 of Set 14 | dourbali
# Processing Record 25 of Set 14 | richards bay
# Processing Record 26 of Set 14 | nizhniy tsasuchey
# Processing Record 27 of Set 14 | pingxiang
# Processing Record 28 of Set 14 | kisangani
# Processing Record 29 of Set 14 | shimoda
# Processing Record 30 of Set 14 | santa maria
# Processing Record 31 of Set 14 | golspie
# Processing Record 32 of Set 14 | la union
# Processing Record 33 of Set 14 | fortuna
# Processing Record 34 of Set 14 | east wenatchee bench
# Processing Record 35 of Set 14 | condado
# Processing Record 36 of Set 14 | barahona
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | moerai
# Processing Record 39 of Set 14 | kwinana
# Processing Record 40 of Set 14 | mwingi
# Processing Record 41 of Set 14 | fort frances
# Processing Record 42 of Set 14 | vila franca do campo
# Processing Record 43 of Set 14 | manzhouli
# Processing Record 44 of Set 14 | plettenberg bay
# Processing Record 45 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 14 | huarmey
# Processing Record 47 of Set 14 | japura
# Processing Record 48 of Set 14 | kutum
# Processing Record 49 of Set 14 | glyadyanskoye
# Processing Record 50 of Set 14 | mao
# Processing Record 1 of Set 15 | lubuagan
# Processing Record 2 of Set 15 | diego de almagro
# Processing Record 3 of Set 15 | salinopolis
# Processing Record 4 of Set 15 | laguna
# Processing Record 5 of Set 15 | palu
# Processing Record 6 of Set 15 | onalaska
# Processing Record 7 of Set 15 | manokwari
# Processing Record 8 of Set 15 | larap
# Processing Record 9 of Set 15 | fare
# Processing Record 10 of Set 15 | fukue
# Processing Record 11 of Set 15 | aswan
# Processing Record 12 of Set 15 | hun
# Processing Record 13 of Set 15 | male
# Processing Record 14 of Set 15 | vallenar
# Processing Record 15 of Set 15 | mayo
# Processing Record 16 of Set 15 | hohhot
# Processing Record 17 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 18 of Set 15 | harigue
# City not found. Skipping...
# Processing Record 19 of Set 15 | ibra
# Processing Record 20 of Set 15 | dhidhdhoo
# Processing Record 21 of Set 15 | cabinda
# Processing Record 22 of Set 15 | hualmay
# Processing Record 23 of Set 15 | banjarmasin
# Processing Record 24 of Set 15 | pokrovskoye
# Processing Record 25 of Set 15 | cabedelo
# Processing Record 26 of Set 15 | aasiaat
# Processing Record 27 of Set 15 | grove city
# Processing Record 28 of Set 15 | skara
# Processing Record 29 of Set 15 | verkhoyansk
# Processing Record 30 of Set 15 | christchurch
# Processing Record 31 of Set 15 | poso
# Processing Record 32 of Set 15 | outjo
# Processing Record 33 of Set 15 | asau
# Processing Record 34 of Set 15 | cartagena
# Processing Record 35 of Set 15 | xuddur
# Processing Record 36 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 15 | chantada
# Processing Record 38 of Set 15 | opuwo
# Processing Record 39 of Set 15 | presidencia roque saenz pena
# Processing Record 40 of Set 15 | bafoulabe
# Processing Record 41 of Set 15 | gushikawa
# Processing Record 42 of Set 15 | tambopata
# Processing Record 43 of Set 15 | galdar
# Processing Record 44 of Set 15 | nandigama
# Processing Record 45 of Set 15 | bulolo
# Processing Record 46 of Set 15 | korem
# Processing Record 47 of Set 15 | souflion
# City not found. Skipping...
# Processing Record 48 of Set 15 | kenai
# Processing Record 49 of Set 15 | bakel
# Processing Record 50 of Set 15 | solhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sumenep  -7.0167  113.8667     84.67        75          91
# 1        Hithadhoo  -0.6000   73.0833     82.22        71          95
# 2            Bluff -46.6000  168.3333     47.80        69          94
# 3             Hilo  19.7297 -155.0900     78.53        77          75
# 4           Dikson  73.5069   80.5464     35.35        87          76
# 5         Hamilton  39.1834  -84.5333     83.73        75           0
# 6   General Cepeda  25.3833 -101.4500     73.08        65          84
# 7          Mataura -46.1927  168.8643     47.48        94         100
# 8     Longyearbyen  78.2186   15.6401     39.04        70          75
# 9  Arraial Do Cabo -22.9661  -42.0278     67.46        77          21
#
#    Wind Speed Country Current Description
# 0       14.36      ID     overcast clouds
# 1        3.89      MV     overcast clouds
# 2       22.24      NZ     overcast clouds
# 3        5.75      US       broken clouds
# 4        6.69      RU       broken clouds
# 5        5.75      US           clear sky
# 6        2.59      MX       broken clouds
# 7        7.65      NZ          light rain
# 8       11.50      SJ       broken clouds
# 9       10.51      BR          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Sumenep      ID  -7.0167  113.8667     84.67        75          91
# 1  Hithadhoo      MV  -0.6000   73.0833     82.22        71          95
# 2      Bluff      NZ -46.6000  168.3333     47.80        69          94
# 3       Hilo      US  19.7297 -155.0900     78.53        77          75
# 4     Dikson      RU  73.5069   80.5464     35.35        87          76
#
#    Wind Speed Current Description
# 0       14.36     overcast clouds
# 1        3.89     overcast clouds
# 2       22.24     overcast clouds
# 3        5.75       broken clouds
# 4        6.69       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
